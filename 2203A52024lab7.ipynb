# %%
import pandas as pd
a=pd.read_csv('/content/drive/MyDrive/Japan_life_expectancy.csv')
a.head()
# Out:
#   Prefecture  Life_expectancy  Physician  Junior_col  University  Public_Hosp  \
# 0      Aichi            84.65      224.4        13.6        23.7         13.7
# 1      Akita            83.79      242.6        11.3        11.9         34.0
# 2     Aomori            82.80      212.5        11.4        11.8         42.9
# 3      Chiba            84.48      205.8        14.7        24.9         16.1
# 4      Ehime            84.24      276.7        14.2        18.0         17.4
#
#    Pshic_hosp  Beds_psic  Nurses  Avg_hours  ...  Park  Forest  \
# 0         0.5      164.3   845.4      171.5  ...  17.2    42.1
# 1         1.7      404.6  1105.5      173.0  ...  10.6    70.3
# 2         1.4      348.7  1108.8      174.5  ...  11.8    63.6
# 3         0.5      195.8   749.1      173.5  ...   5.5    30.1
# 4         1.0      329.7  1277.5      178.0  ...   7.2    70.5
#
#    Income_per capita  Density_pop  Hospitals    Beds  Ambulances  Health_exp  \
# ...

# %%
p=a.drop(columns=['Prefecture'])
print(p)

# %%
#normalize data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(p)
nd = scaler.transform(p)
#print(nd)
p.loc[:, :]=nd
p.head()
# Out:
#    Life_expectancy  Physician  Junior_col  University  Public_Hosp  \
# 0         0.685185   0.290162    0.410714    0.601010     0.151079
# 1         0.366667   0.403487    0.000000    0.005051     0.637890
# 2         0.000000   0.216065    0.017857    0.000000     0.851319
# 3         0.622222   0.174346    0.607143    0.661616     0.208633
# 4         0.533333   0.615816    0.517857    0.313131     0.239808
#
#    Pshic_hosp  Beds_psic    Nurses  Avg_hours    Salary  ...      Park  \
# 0        0.10   0.037120  0.150955   0.071429  0.525273  ...  0.387195
# 1        0.70   0.574463  0.428632   0.285714  0.022645  ...  0.185976
# 2        0.55   0.449463  0.432155   0.500000  0.000000  ...  0.222561
# 3        0.10   0.107558  0.048148   0.357143  0.488880  ...  0.030488
# 4        0.35   0.406977  0.612256   1.000000  0.145572  ...  0.082317
#
#      Forest  Income_per capita  Density_pop  Hospitals      Beds  Ambulances  \
# ...

# %%
y=p['Life_expectancy']
print("target:\n",y)
# Out:
# target:
#  0     0.685185
# 1     0.366667
# 2     0.000000
# 3     0.622222
# 4     0.533333
# 5     0.781481
# 6     0.644444
# 7     0.337037
# 8     0.707407
# 9     0.503704
# 10    0.837037
# 11    0.444444
# 12    0.744444
# 13    0.414815
# 14    0.837037
# 15    0.388889
# 16    0.666667
# 17    0.533333
# 18    0.803704
# 19    0.562963
# 20    0.840741
# 21    0.907407
# 22    0.681481
# 23    0.670370
# 24    0.585185
# 25    0.985185
# 26    0.522222
# 27    0.881481
# 28    0.603704
# 29    0.781481
# 30    0.851852
# 31    0.559259
# 32    0.477778
# 33    0.666667
# 34    0.585185
# 35    1.000000
# 36    0.785185
# 37    0.644444
# 38    0.425926
# 39    0.574074
# 40    0.748148
# 41    0.677778
# 42    0.762963
# 43    0.518519
# 44    0.588889
# 45    0.548148
# 46    0.751852
# Name: Life_expectancy, dtype: float64

# %%
x=p.drop(columns=['Life_expectancy'])
print("feactures:\n",x)
# Out:
# feactures:
#      Physician  Junior_col  University  Public_Hosp  Pshic_hosp  Beds_psic  \
# 0    0.290162    0.410714    0.601010     0.151079        0.10   0.037120
# 1    0.403487    0.000000    0.005051     0.637890        0.70   0.574463
# 2    0.216065    0.017857    0.000000     0.851319        0.55   0.449463
# 3    0.174346    0.607143    0.661616     0.208633        0.10   0.107558
# 4    0.615816    0.517857    0.313131     0.239808        0.35   0.406977
# 5    0.498755    0.285714    0.353535     0.369305        0.50   0.305009
# 6    0.822540    0.517857    0.434343     0.035971        0.45   0.579830
# 7    0.173724    0.053571    0.065657     0.316547        0.50   0.429562
# 8    0.290785    0.375000    0.338384     0.414868        0.15   0.106216
# 9    0.348692    0.607143    0.287879     0.218225        0.20   0.245528
# 10   0.556040    0.857143    0.570707     0.160671        0.40   0.362254
# ...

# %%
import math
X=p
print("enter the splitting of ration train and test: ")
s_f = float(input())
n_train = math.floor(s_f *X.shape[0])
n_test = math.ceil((1-s_f) * X.shape[0])
X_train = x[:n_train]
Y_train = y[:n_train]
X_test = x[n_train:]
Y_test = y[n_train:]
print("Total Number of rows in train:",X_train.shape[0])
print("Total Number of rows in test:",Y_test.shape[0])
# Out:
# enter the splitting of ration train and test:
# 0.8
# Total Number of rows in train: 37
# Total Number of rows in test: 10

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X_train, Y_train)

# Make predictions on the training data
y_pred=model.predict(X_train)
# Calculate the mean squared error
mse = mean_squared_error(Y_train, y_pred)

print("Mean squared error linear regression training:", mse)
# Out:
# Mean squared error: 0.003474880920806942

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
# Create a linear regression model
model = LinearRegression()

# Fit the model to the data
model.fit(X_test, Y_test)

# Make predictions on the training data
y_pred=model.predict(X_test)
# Calculate the mean squared error
mse = mean_squared_error(Y_test, y_pred)

print("Mean squared error using linear regression testing data:", mse)
# Out:
# Mean squared error using linear regression testing data: 2.2186712959340958e-32

# %%
from sklearn.linear_model import Ridge
ridge_model=Ridge()
ridge_model.fit(X_train,Y_train)
y_pred_ridge_test=ridge_model.predict(X_test)
y_pred_ridge_train=ridge_model.predict(X_train)
mse_ridge_test=mean_squared_error(Y_test,y_pred_ridge_test)
mse_ridge_train=mean_squared_error(Y_train,y_pred_ridge_train)

print("Ridge Mse(TEST):",mse_ridge_test)
print("Ridge Mse(TRAIN):",mse_ridge_train)
# Out:
# Ridge Mse(TEST): 0.02284512939629985
# Ridge Mse(TRAIN): 0.009605606252484895

# %%
from sklearn.linear_model import Lasso
laaso_reg = Lasso(alpha=0.1)

# Fit the model to the training data
lasso_reg.fit(X_train, Y_train)

# Make predictions on the testing data
y_pred = lasso_reg.predict(X_test)

# Calculate the mean squared error
mse = mean_squared_error(Y_test, y_pred)
print("lasso Mean Squared Error test:", mse)
# Out:
# lasso Mean Squared Error test: 0.011789267746224543

# %%
from sklearn.linear_model import Lasso
laaso_reg = Lasso(alpha=0.1)

# Fit the model to the training data
lasso_reg.fit(X_traint, Y_train)

# Make predictions on the testing data
y_pred = lasso_reg.predict(X_train)

# Calculate the mean squared error
mse = mean_squared_error(Y_train, y_pred)
print(" lasso Mean Squared Error train:", mse)
# Out:
#  lasso Mean Squared Error train: 0.04037342898454002
